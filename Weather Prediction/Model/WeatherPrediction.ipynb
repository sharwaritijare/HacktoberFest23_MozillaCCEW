# %%
import pandas as pd

weather=pd.read_csv("weather.csv",index_col="DATE")

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2023-10-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  18.12
# 2023-10-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  13.42
# 2023-10-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   6.71
# 2023-10-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
# 2023-10-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
# ...

# %%
null_percentage=weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
null_percentage
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.510513
# ACSH       0.510462
# AWND       0.260500
# FMTM       0.484600
# PGTM       0.375401
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000051
# TAVG       0.668126
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998422
# WDF1       0.510716
# WDF2       0.489691
# WDF5       0.493916
# WDFG       0.739296
# WDFM       0.999949
# WESD       0.690933
# WSF1       0.510564
# WSF2       0.489691
# WSF5       0.493967
# WSFG       0.620068
# WSFM       0.999949
# WT01       0.629741
# WT02       0.935142
# WT03       0.932750
# WT04       0.982538
# WT05       0.981469
# WT06       0.990786
# WT07       0.994502
# WT08       0.799267
# WT09       0.992873
# WT11       0.999287
# WT13       0.888764
# WT14       0.954844
# WT15       0.997862
# WT16       0.665173
# WT17       0.996945
# WT18       0.940590
# WT19       0.999949
# WT21       0.999745
# WT22       0.997505
# WV01       0.999949
# ...

# %%
# clean up the data
valid_columns=weather.columns[null_percentage<0.05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather=weather[valid_columns].copy()

# %%
weather
# Out:
#                 STATION                              NAME  PRCP  SNOW  SNWD  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-10-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             TMAX  TMIN
# DATE
# ...

# %%
weather.columns=weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-10-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# ...

# %%
weather=weather.ffill()

# %%
# checking again for null values:
null_percentage=weather.apply(pd.isnull).sum()

# %%
null_percentage
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2023-10-03', '2023-10-04', '2023-10-05', '2023-10-06', '2023-10-07',
#        '2023-10-08', '2023-10-09', '2023-10-10', '2023-10-11', '2023-10-12'],
#       dtype='object', name='DATE', length=19643)

# %%
# converting the index into  datetime type
weather.index=pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2023-10-03', '2023-10-04', '2023-10-05', '2023-10-06',
#                '2023-10-07', '2023-10-08', '2023-10-09', '2023-10-10',
#                '2023-10-11', '2023-10-12'],
#               dtype='datetime64[ns]', name='DATE', length=19643, freq=None)

# %%
# checking some gaps if too many gaps then we have to handle the gaps
weather.index.year.value_counts().sort_index()
# Out:
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    285
# Name: DATE, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
weather["target"]=weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-10-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
weather=weather.ffill()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-10-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
# Applying ridge regression(linear regression method) machine learning model:
from sklearn.linear_model import Ridge

# %%
# correlation
weather.corr()
# Out:
#             prcp      snow      snwd      tmax      tmin    target
# prcp    1.000000  0.147903  0.001063 -0.007260  0.052537 -0.002927
# snow    0.147903  1.000000  0.232807 -0.174142 -0.158361 -0.171831
# snwd    0.001063  0.232807  1.000000 -0.258256 -0.255227 -0.239577
# tmax   -0.007260 -0.174142 -0.258256  1.000000  0.955229  0.915125
# tmin    0.052537 -0.158361 -0.255227  0.955229  1.000000  0.915214
# target -0.002927 -0.171831 -0.239577  0.915125  0.915214  1.000000

# %%
rr=Ridge(alpha=.1)

# %%
predictors=weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather,model,predictors,start=3650,step=90):
    all_predictions=[]
    
    for i in range(start,weather.shape[0],step):
        train=weather.iloc[:i,:]
        test=weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors],train["target"])
        
        preds=model.predict(test[predictors])
        
        preds=pd.Series(preds, index=test.index)
        combined=pd.concat([test["target"],preds],axis=1)
        combined.columns=["actual","prediction"]
        combined["diff"]=(combined["prediction"]-combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions=backtest(weather,rr,predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2023-10-08    62.0   62.893461   0.893461
# 2023-10-09    64.0   62.825185   1.174815
# 2023-10-10    69.0   64.754134   4.245866
# 2023-10-11    68.0   66.994632   1.005368
# 2023-10-12    68.0   66.546532   1.453468
#
# [15993 rows x 3 columns]

# %%
# mean absolute error:
from sklearn.metrics import mean_absolute_error,mean_squared_error,accuracy_score

mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 5.136602476901772

# %%
def percentage_diff(old,new):
    return (new-old)/old

def compute_rolling(weather,horizon,col):
    label= f"rolling_{horizon}_{col}"
    
    weather[label]=weather[col].rolling(horizon).mean()
    weather[f"{label}_percentage"]=percentage_diff(weather[label],weather[col])
    return weather

rolling_horizons=[3,14]

for horizon in rolling_horizons:
    for col in ["tmax","tmin","prcp"]:
        weather=compute_rolling(weather,horizon,col)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-10-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
weather=weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-10-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
weather=weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax","tmin","prcp"]:
    weather[f"month_avg{col}"]=weather[col].groupby(weather.index.month,group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"]=weather[col].groupby(weather.index.day_of_year,group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-10-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-10-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
predictors=weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rolling_3_tmax',
#        'rolling_3_tmax_percentage', 'rolling_3_tmin',
#        'rolling_3_tmin_percentage', 'rolling_3_prcp',
#        'rolling_3_prcp_percentage', 'rolling_14_tmax',
#        'rolling_14_tmax_percentage', 'rolling_14_tmin',
#        'rolling_14_tmin_percentage', 'rolling_14_prcp',
#        'rolling_14_prcp_percentage', 'month_avgtmax', 'day_avg_tmax',
#        'month_avgtmin', 'day_avg_tmin', 'month_avgprcp', 'day_avg_prcp'],
#       dtype='object')

# %%
predictions=backtest(weather,rr,predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1980-01-13    54.0   32.433990  21.566010
# 1980-01-14    51.0   44.779815   6.220185
# 1980-01-15    45.0   46.865181   1.865181
# 1980-01-16    40.0   42.196335   2.196335
# 1980-01-17    41.0   40.815128   0.184872
# ...            ...         ...        ...
# 2023-10-08    62.0   62.210575   0.210575
# 2023-10-09    64.0   63.204850   0.795150
# 2023-10-10    69.0   66.534616   2.465384
# 2023-10-11    68.0   67.786097   0.213903
# 2023-10-12    68.0   67.299858   0.700142
#
# [15979 rows x 3 columns]

# %%
predictions.sort_values("diff",ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.393216  30.606784
# 1998-03-26    80.0   51.960174  28.039826
# 2007-03-26    78.0   49.972150  28.027850
# 2003-04-15    86.0   59.412927  26.587073
# 1985-04-18    84.0   58.323966  25.676034
# ...            ...         ...        ...
# 1984-04-23    55.0   54.998397   0.001603
# 1985-07-05    80.0   79.998678   0.001322
# 2016-06-29    85.0   84.999142   0.000858
# 2012-06-25    76.0   76.000675   0.000675
# 2004-10-02    69.0   68.999594   0.000406
#
# [15979 rows x 3 columns]

# %%
mae=mean_absolute_error(predictions["actual"],predictions["prediction"])
print(f"Mean absolute Error: {mae}")
# Out:
# Mean absolute Error: 4.787234737008247

# %%
mse = mean_squared_error(predictions["actual"],predictions["prediction"])
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 37.51533902844963

# %%
weather.loc["1990-03-07":"1990-03-17"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
# ...

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
# Random Forest:

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# Define the features (predictors) and target variable

features = ["prcp", "snow", "snwd", "tmax", "tmin", "rolling_3_tmax", "rolling_14_tmax", "rolling_3_tmax_percentage", "rolling_14_tmax_percentage", "rolling_14_prcp", "rolling_14_prcp_percentage"]

target = "target"

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(weather[features], weather[target], test_size=0.2, random_state=42)

# %%
# Initialize the Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
# Train the model on the training data
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Make predictions on the test data
y_pred = rf_model.predict(X_test)

# %%
# Calculate the mean absolute error
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean absolute Error: {mae}")
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean absolute Error: 4.899077941925624
# Mean Squared Error: 39.66109383596536

# %%
mae
# Out:
# 4.899077941925624

# %%
y_pred
# Out:
# array([84.94, 49.92, 47.98, ..., 80.  , 78.01, 51.11])

# %%
# knn Regressor :

# %%
# knn
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor  # for regression
from sklearn.metrics import accuracy_score, mean_squared_error

# %%
knn_regressor = KNeighborsRegressor(n_neighbors=5, weights='uniform')

# Fit the model to the training data
knn_regressor.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = knn_regressor.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 44.9335812531839

# %%
mae = mean_absolute_error(y_test, y_pred)

# %%
mae
# Out:
# 5.2059602649006615

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your data is in a DataFrame called 'weather'
# If you have a different name, replace 'weather' with your DataFrame's name.

# Example 1: Creating a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=weather, x="tmax", y="tmin", hue="prcp", palette='viridis')
plt.title('Scatter Plot of TMAX vs TMIN')
plt.xlabel('TMAX')
plt.ylabel('TMIN')
plt.show()

# Example 2: Creating a histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=weather, x="tmax", kde=True, color='skyblue')
plt.title('Histogram of TMAX')
plt.xlabel('TMAX')
plt.show()

# Example 3: Creating a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=weather, x="prcp", y="tmax", palette='Set2')
plt.title('Box Plot of TMAX vs PRCP')
plt.xlabel('PRCP')
plt.ylabel('TMAX')
plt.show()


plt.figure(figsize = (8,8))
sns.heatmap(weather.corr())
# Out:
# <AxesSubplot:>
